# %% [markdown]
# # Lab | Web Scraping

# %% [markdown]
# Welcome to the "Books to Scrape" Web Scraping Adventure Lab!
#
# **Objective**
#
# In this lab, we will embark on a mission to unearth valuable insights from the data available on Books to Scrape, an online platform showcasing a wide variety of books. As data analyst, you have been tasked with scraping a specific subset of book data from Books to Scrape to assist publishing companies in understanding the landscape of highly-rated books across different genres. Your insights will help shape future book marketing strategies and publishing decisions.
#
# **Background**
#
# In a world where data has become the new currency, businesses are leveraging big data to make informed decisions that drive success and profitability. The publishing industry, much like others, utilizes data analytics to understand market trends, reader preferences, and the performance of books based on factors such as genre, author, and ratings. Books to Scrape serves as a rich source of such data, offering detailed information about a diverse range of books, making it an ideal platform for extracting insights to aid in informed decision-making within the literary world.
#
# **Task**
#
# Your task is to create a Python script using BeautifulSoup and pandas to scrape Books to Scrape book data, focusing on book ratings and genres. The script should be able to filter books with ratings above a certain threshold and in specific genres. Additionally, the script should structure the scraped data in a tabular format using pandas for further analysis.
#
# **Expected Outcome**
#
# A function named `scrape_books` that takes two parameters: `min_rating` and `max_price`. The function should scrape book data from the "Books to Scrape" website and return a `pandas` DataFrame with the following columns:
#
# **Expected Outcome**
#
# - A function named `scrape_books` that takes two parameters: `min_rating` and `max_price`.
# - The function should return a DataFrame with the following columns:
#   - **UPC**: The Universal Product Code (UPC) of the book.
#   - **Title**: The title of the book.
#   - **Price (£)**: The price of the book in pounds.
#   - **Rating**: The rating of the book (1-5 stars).
#   - **Genre**: The genre of the book.
#   - **Availability**: Whether the book is in stock or not.
#   - **Description**: A brief description or product description of the book (if available).
#
# You will execute this script to scrape data for books with a minimum rating of `4.0 and above` and a maximum price of `£20`.
#
# Remember to experiment with different ratings and prices to ensure your code is versatile and can handle various searches effectively!
#
# **Resources**
#
# - [Beautiful Soup Documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Pandas Documentation](https://pandas.pydata.org/pandas-docs/stable/index.html)
# - [Books to Scrape](https://books.toscrape.com/)

# %% [markdown]
# **Hint**
#
# Your first mission is to familiarize yourself with the **Books to Scrape** website. Navigate to [Books to Scrape](http://books.toscrape.com/) and explore the available books to understand their layout and structure.
#
# Next, think about how you can set parameters for your data extraction:
#
# - **Minimum Rating**: Focus on books with a rating of 4.0 and above.
# - **Maximum Price**: Filter for books priced up to £20.
#
# After reviewing the site, you can construct a plan for scraping relevant data. Pay attention to the details displayed for each book, including the title, price, rating, and availability. This will help you identify the correct HTML elements to target with your scraping script.
#
# Make sure to build your scraping URL and logic based on the patterns you observe in the HTML structure of the book listings!

# %% [markdown]
# ---
#
# **Best of luck! Immerse yourself in the world of books, and may the data be with you!**

# %% [markdown]
# **Important Note**:
#
# In the fast-changing online world, websites often update and change their structures. When you try this lab, the **Books to Scrape** website might differ from what you expect.
#
# If you encounter issues due to these changes, like new rules or obstacles preventing data extraction, don’t worry! Get creative.
#
# You can choose another website that interests you and is suitable for scraping data. Options like Wikipedia, The New York Times, or even library databases are great alternatives. The main goal remains the same: extract useful data and enhance your web scraping skills while exploring a source of information you enjoy. This is your opportunity to practice and adapt to different web environments!

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://books.toscrape.com"

r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.content)

# %%
# Finding all products

books = soup.find_all("article", attrs = {"class": "product_pod"})
books
# Out:
# [<article class="product_pod">
#  <div class="image_container">
#  <a href="catalogue/a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
#  </div>
#  <p class="star-rating Three">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
#  <div class="product_price">
#  <p class="price_color">£51.77</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>,
#  <article class="product_pod">
#  <div class="image_container">
# ...

# %%
## Title

books[0].find_all("img")[0]["alt"]
# Out:
# 'A Light in the Attic'

# %%
## Price

float(books[0].find_all("p", attrs = {"class" : "price_color"})[0].get_text().replace("£", ""))
# Out:
# 51.77

# %%
## Rating

books[0].find_all("p", attrs = {"class" : "star-rating"})[0].get("class")[1]
# Out:
# 'Three'

# %%
def get_rating(book):
    
    rating = book.find_all("p", attrs = {"class" : "star-rating"})[0].get("class")[1]
    
    if rating == "One":
        return 1
    elif rating == "Two":
        return 2
    elif rating == "Three":
        return 3
    elif rating == "Four":
        return 4
    else:
        return 5

# %%
get_rating(book)
# Out:
# 5

# %%
## Availability

books[0].find_all("p", attrs = {"class" : "instock availability"})[0].get_text().replace("\n", "").strip()
# Out:
# 'In stock'

# %%
books[0].find("a")["href"]
# Out:
# 'catalogue/a-light-in-the-attic_1000/index.html'

# %%
books[0].find_all("a")[0]["href"].replace("catalogue/","")
# Out:
# 'a-light-in-the-attic_1000/index.html'

# %%
# Finding the url

domain = "https://books.toscrape.com/catalogue/"

def get_url(book, domain = "https://books.toscrape.com/catalogue/"):
  href = book.find_all("a")[0]["href"].replace("catalogue/","")
  url = domain+href  

  return url

# %%
# Find 
## UPC
## Genre
## Description

def get_upc(url):

    r = requests.get(url)
    soup = BeautifulSoup(r.content)

    upc = soup.find_all("td")[0].get_text()
     
    return upc

def get_availability(url):

    r = requests.get(url)
    soup = BeautifulSoup(r.content)

    availability = soup.find_all("td")[5].get_text()
     
    return availability


def get_description(url):

    r = requests.get(url)
    soup = BeautifulSoup(r.content)

    description = soup.find_all("p", class_ = False)[0].get_text()
     
    return description

upc, availability, description

# def get_book_info(url):

#     r = requests.get(url)
#     soup = BeautifulSoup(r.content)

#     upc = soup.find_all("td")[0].get_text()
#     availability = soup.find_all("td")[5].get_text()
#     description = soup.find_all("p", class_ = False)[0].get_text()
     
#     return upc, availability, description

# upc, availability, description = get_book_info(url)
# Out:
# ('a22124811bfa8350',
#  'In stock (19 available)',
# ...

# %%
book_dict = {}
index = 0

for book in books:

    rating = get_rating(book)
    price = float(book.find_all("p", attrs = {"class" : "price_color"})[0].get_text().replace("£", ""))
    url = get_url(book, domain)

    if price <= 20 and rating > 4: 
        book_dict[index] = {
            "title": book.find_all("img")[0]["alt"],
            "price": price,
            "rating": rating,
            "url": url,
            "upc": get_upc(url),
            "availability": get_availability(url),
            "description": get_description(url)        
        }

        index += 1

book_dict
# Out:
# {0: {'title': 'Set Me Free',
#   'price': 17.46,
#   'rating': 5,
#   'url': 'https://books.toscrape.com/catalogue/set-me-free_988/index.html',
#   'upc': 'ce6396b0f23f6ecc',
#   'availability': 'In stock (19 available)',
# ...

# %%
# Get books per page

url = domain+"page-1.html"

def get_book_dictionary(url, domain):

    r = requests.get(url)
    soup = BeautifulSoup(r.content)
    
    books = soup.find_all("article", attrs = {"class": "product_pod"})

    book_dict = {}
    index = 0

    for book in books:

        rating = get_rating(book)
        price = float(book.find_all("p", attrs = {"class" : "price_color"})[0].get_text().replace("£", ""))
        url = get_url(book, domain)
        title = book.find_all("img")[0]["alt"]

        if price >= 2 and rating < 4: 
            book_dict[index] = {
                "title": title,
                "price": price,
                "rating": rating,
                "url": url,
                "upc": get_upc(url),
                "availability": get_availability(url),
                "description": get_description(url)        
            }

            index += 1
            
    return book_dict

# %%
get_book_dictionary(url, domain)
# Out:
# {0: {'title': 'A Light in the Attic',
#   'price': 51.77,
#   'rating': 3,
#   'url': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html',
#   'upc': 'a897fe39b1053632',
#   'availability': 'In stock (22 available)',
# ...

# %%
import pandas as pd

books_df = pd.DataFrame.from_dict(books_dict, orient='index')
books_df
# Out:
#                                                title  price  rating  \
# 0  The Coming Woman: A Novel Based on the Life of...  17.93       3
# 1     Starving Hearts (Triangular Trade Trilogy, #1)  13.99       2
#
#                                                  url               upc  \
# 0  https://books.toscrape.com/catalogue/the-comin...  e72a5dfc7e9267b2
# 1  https://books.toscrape.com/catalogue/starving-...  0312262ecafa5a40
#
#               availability                                        description
# 0  In stock (19 available)  "If you have a heart, if you have a soul, Kare...
# 1  In stock (19 available)  Since her assault, Miss Annette Chetwynd has b...

# %%
def get_all_books(pages=1):
    
    books_multiple_pages_list = []
    
    for page in range(1, pages+1):

        books = soup.find_all("article", attrs = {"class": "product_pod"})
        domain = "https://books.toscrape.com/catalogue/"

        page_dict = get_book_dictionary(url, domain)

        for key, book_data in page_dict.items():
            books_multiple_pages_list.append(book_data)

    return books_multiple_pages_list

# %%
books_multiple_pages_list = get_all_books(pages=2)
books_multiple_pages_list
# Out:
# [{'title': 'A Light in the Attic',
#   'price': 51.77,
#   'rating': 3,
#   'url': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html',
#   'upc': 'a897fe39b1053632',
#   'availability': 'In stock (22 available)',
# ...

# %%
books_multiple_pages_df = pd.DataFrame(books_multiple_pages_list)
books_multiple_pages_df
# Out:
#                                                 title  price  rating  \
# 0                                A Light in the Attic  51.77       3
# 1                                  Tipping the Velvet  53.74       1
# 2                                          Soumission  50.10       1
# 3                                     The Requiem Red  22.65       1
# 4   The Coming Woman: A Novel Based on the Life of...  17.93       3
# 5                                     The Black Maria  52.15       1
# 6      Starving Hearts (Triangular Trade Trilogy, #1)  13.99       2
# 7   Our Band Could Be Your Life: Scenes from the A...  57.25       3
# 8                                                Olio  23.88       1
# 9   Mesaerion: The Best Science Fiction Stories 18...  37.59       1
# 10                       Libertarianism for Beginners  51.33       2
# 11                            It's Only the Himalayas  45.17       2
# 12                               A Light in the Attic  51.77       3
# ...
